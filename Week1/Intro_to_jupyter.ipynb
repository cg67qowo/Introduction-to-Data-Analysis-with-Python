# %% [markdown]
# ## Introduction to Python and Jupyter
# We will now see how a Jupyter Notebook is structured and run basic Python programs.
#
# A notebook is a series of cell, that can be *markdown* or *code*. The markdown cells (like this one) can contain text. While in this class you will mostly see text in the markdown cells, you can also display mathematical equations, images, and many other things. For the project that you will submit, I recommend using a notebook for your code, and submitting it with comments and explanations.
#
# A few key points about markdown usage:
#
# 1. Headings
# Use `#` symbols for headings:
#       # Heading 1
#       ## Heading 2
#       ### Heading 3
#
# 2. Text Styling
# - *Italic*: `*italic*` → *italic*
# - **Bold**: `**bold**` → **bold**
# - Inline code: `` `code` `` → `code`
#
# 3. Lists
# - Unordered list (using `-`, `*`, or `+`):
#   - Item 1
#   - Item 2
#     - Subitem
#
# 1. Ordered list
# 2. Second item
# 3. Third item
#
#
# 4. Links and Images
# - Link: [GitHub](https://github.com)
# - Image: ![image name](image link)
#
#
# 5. Code Blocks
# Inline code: `` `print("Hello")` `` → `print("Hello")`
#
#
# You can also write text (that you do not intend to execute) in a code cell, marked as a **comment**: see how in the next cell.

# %%
# This is a comment: you write # before the line
# Please note that this only works for commenting out a line
"""
However,
you can write multiline comments
by typing three quotes before and after.
"""

# %% [markdown]
# In class, we talked about control flows. Here are some exercises to deepen your knowledge:

# %%
# write a loop that iterates through all numbers lower than 11, and prints them.
# you can write it in this cell, below the comment

# %%
x = 5
y = 3
z = 4
# Suppose these are the three sides of a triangle.
# Write a conditional statement that prints out "Equilateral" if the triangle is equilateral, and "non equilateral" otherwise.
# Hint: Even though you see that the triangle is not equilateral by looking at the numbers, you still need to check it with an if statement
