# %% [markdown]
# ### Homework - Introduction to Python - Week 1
#
# ##### Control flows

# %%
# write a loop that iterates through all numbers lower than 11, and prints them.

# %%
# Here is an example of a nested loop:

# inner loop
n = 6

# outer loop
for i in range(rows):
    # nested loop
    for j in range(i):
        # display number
        print(i, end=' ')
    # new line after each row
    print('')
